# %%
import pandas as pd

# casualties of storms in America based in EMDAT datasets
data = pd.read_excel(r'Data sets\2000-2022-emdat_public_2022_04_24_query_uid-XuKaJG.xlsx', sheet_name="Filtered Data Level 2")
df = pd.DataFrame(data)
df.iloc[:,[0,1,6,7,9, 12, 13, 34, 35, 36, 37,38, 40, 41, 42, 43, 44]]
# Out:
#             Dis No  Year Disaster Type  Disaster Subtype  \
# 0    2000-0642-BLZ  2000         Storm  Tropical cyclone
# 1    2000-0643-MEX  2000         Storm  Tropical cyclone
# 2    2000-0644-NIC  2000         Storm  Tropical cyclone
# 3    2000-0645-SLV  2000         Storm  Tropical cyclone
# 4    2000-0652-USA  2000         Storm  Tropical cyclone
# ..             ...   ...           ...               ...
# 381  2021-0531-USA  2021         Storm  Tropical cyclone
# 382  2021-0532-USA  2021         Storm  Tropical cyclone
# 383  2021-0551-USA  2021         Storm  Tropical cyclone
# 384  2021-0583-USA  2021         Storm  Tropical cyclone
# 385  2021-0373-VCT  2021         Storm  Tropical cyclone
#
#                       Event Name            Region Continent  Total Deaths  \
# 0                          Keith   Central America  Americas          14.0
# 1                          Keith   Central America  Americas          23.0
# 2                          Keith   Central America  Americas           1.0
# 3                          Keith   Central America  Americas           1.0
# 4                         Leslie  Northern America  Americas           2.0
# ..                           ...               ...       ...           ...
# 381  Tropical depression 'Henri'  Northern America  Americas           NaN
# 382        Tropical storm 'Fred'  Northern America  Americas           7.0
# 383         Tropical storm 'Ida'  Northern America  Americas          96.0
# 384    Tropical storm 'Nicholas'  Northern America  Americas           NaN
# 385             Hurricane 'Elsa'         Caribbean  Americas           NaN
#
#      No Injured  No Affected  No Homeless  Total Affected  \
# 0         570.0      62000.0          NaN         62570.0
# 1           NaN      30000.0          NaN         30000.0
# 2           NaN       2300.0          NaN          2300.0
# 3           NaN        100.0          NaN           100.0
# 4           NaN      14418.0       3015.0         17433.0
# ..          ...          ...          ...             ...
# 381         NaN         86.0          NaN            86.0
# 382         NaN        105.0          NaN           105.0
# 383         NaN      14000.0          NaN         14000.0
# 384         NaN          NaN          NaN             NaN
# 385         NaN        129.0          NaN           129.0
#
#      Reconstruction Costs, Adjusted ('000 US$)  Insured Damages ('000 US$)  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
# ..                                         ...                         ...
# 381                                        NaN                         NaN
# 382                                        NaN                         NaN
# 383                                        NaN                  36000000.0
# 384                                        NaN                         NaN
# 385                                        NaN                         NaN
#
#      Insured Damages, Adjusted ('000 US$)  Total Damages ('000 US$)  \
# 0                                     NaN                  277460.0
# 1                                     NaN                    1000.0
# 2                                     NaN                    1000.0
# 3                                     NaN                       NaN
# 4                                     NaN                  219000.0
# ..                                    ...                       ...
# 381                                   NaN                  550000.0
# 382                                   NaN                 1300000.0
# 383                            36000000.0                65000000.0
# 384                                   NaN                 1000000.0
# 385                                   NaN                       NaN
#
#      Total Damages, Adjusted ('000 US$)
# 0                              436604.0
# 1                                1574.0
# 2                                1574.0
# 3                                   NaN
# 4                              344613.0
# ..                                  ...
# 381                            550000.0
# 382                           1300000.0
# 383                          65000000.0
# 384                           1000000.0
# 385                                 NaN
#
# [386 rows x 17 columns]
