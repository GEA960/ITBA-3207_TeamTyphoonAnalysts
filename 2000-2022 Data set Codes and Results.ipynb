# %% [markdown]
# The Centre for Research on the Epidemiology of Disasters' Data set about the American Typhoons (2000-2022)
#
# 	  1. Determine the typhoon(s) from 2000-2022 that brought the greatest number of casualties to the different locations in America.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# casualties of storms in America based in EMDAT datasets
data = pd.read_excel(r'Data sets\2000-2022-emdat_public_2022_04_24_query_uid-XuKaJG.xlsx', sheet_name="Filtered Data Level 2")

df = pd.DataFrame(data) #convert dataset into dataframe

df = df.fillna(0) # replace NaN with zero value

                    #*************************NEW DATAFRAME***************************************
    
#selecting all needed and specific columns from original dataframe/dataset and creating new dataframe named new_df
new_df = df.iloc[:,[0,1,6,7,9,10, 12,34, 35, 36, 37,38, 40, 41, 42, 43, 44, 22]].copy()
    #changing data types of specific columns using dictionary
convert_datatypes = {"Total Deaths":int,
                     "No Injured":int,
                     "No Affected":int,
                     "No Homeless":int,
                     "Total Affected":int,
                     "Reconstruction Costs, Adjusted ('000 US$)": int,
                     "Insured Damages ('000 US$)": int,
                     "Insured Damages, Adjusted ('000 US$)": int,
                     "Total Damages ('000 US$)":int,
                     "Total Damages, Adjusted ('000 US$)": int}
new_df= new_df.astype(convert_datatypes) #converting columns datatypes
new_df.loc[9,"Event Name"]="Michelle"
new_df.loc[260,"Event Name"]="Hurricane 'Joaquin'"

                    #***********************SUB DATAFRAME (YEAR 2000)***************************
    
#creating subdataframe name=typ_y2000 and selecting rows where year=2000
typ_y2000 = new_df.loc[new_df['Year']==2000].copy()

#selecting columns for sorting based on column "Total Affected"
typ_y2000_af = typ_y2000.iloc[:,[0,1,3,4,5,11]] 
typ_y2000_af = typ_y2000_af.sort_values(by = 'Total Affected', ascending = False) #sorting of data in descending order
print('\nYear:2000 \n(Sorted by column: Total Affected)')
display(typ_y2000_af) #displaying of selected data
        
#selecting columns for sorting based on column "Total Deaths"
typ_y2000_d = typ_y2000.iloc[:,[0,1,3,4,5,7]] 
typ_y2000_d = typ_y2000_d.sort_values(by = 'Total Deaths', ascending = False) #sorting of data in descending order
print('\n(Sorted by column: Total Deaths)')
display(typ_y2000_d) #displaying of selected data


#************************

#graphing of Data for Total Affected
TAdata_2000 = {"Keith": 94970, "Leslie": 17433 }
typ_name = list(TAdata_2000.keys())
values = list(TAdata_2000.values())

plt.bar(typ_name, values, color ='blue',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2000 \n (in terms of Total Number of Affected Person)")
plt.show()


#graphing of Data for Total Deaths
TDdata_2000 = {"Keith": 39, "Leslie": 2 }
typ_name1 = list(TDdata_2000.keys())
values1 = list(TDdata_2000.values())

plt.bar(typ_name1, values1, color ='red',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2000 \n (in terms of Total Number of Death)")
plt.show()
# Out:
# Year:2000
# (Sorted by column: Total Affected)
#           Dis No  Year  Disaster Subtype Event Name  \
# 0  2000-0642-BLZ  2000  Tropical cyclone      Keith
# 1  2000-0643-MEX  2000  Tropical cyclone      Keith
# 4  2000-0652-USA  2000  Tropical cyclone     Leslie
# 2  2000-0644-NIC  2000  Tropical cyclone      Keith
# 3  2000-0645-SLV  2000  Tropical cyclone      Keith
#
#                           Country  Total Affected
# 0                          Belize           62570
# 1                          Mexico           30000
# 4  United States of America (the)           17433
# 2                       Nicaragua            2300
# 3                     El Salvador             100
# (Sorted by column: Total Deaths)
#           Dis No  Year  Disaster Subtype Event Name  \
# 1  2000-0643-MEX  2000  Tropical cyclone      Keith
# 0  2000-0642-BLZ  2000  Tropical cyclone      Keith
# 4  2000-0652-USA  2000  Tropical cyclone     Leslie
# 2  2000-0644-NIC  2000  Tropical cyclone      Keith
# ...

# %%
from IPython.display import display_html 

    #***********************SUB DATAFRAME (YEAR 2001)***************************
    
#creating subdataframe name=typ_y2001 and selecting rows where year=2001
typ_y2001 = new_df.loc[new_df['Year']==2001].copy()
typhoon_names = typ_y2001.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected = typhoon_names['Total Affected'].sum()
data2001 = pd.DataFrame(TotalAffected)
Sorted_Data_TA = data2001.sort_values(by='Total Affected',ascending=False)
resultTA = Sorted_Data_TA.head(5)

#selecting data by column Total Affected
TotalDeath = typhoon_names['Total Deaths'].sum()
data2001_d = pd.DataFrame(TotalDeath)
Sorted_Data_TD = data2001_d.sort_values(by='Total Deaths',ascending=False)
resultTD = Sorted_Data_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2001_TA_styler = resultTA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2001)')
tb2001_TD_styler = resultTD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2001)')

display_html(tb2001_TA_styler._repr_html_()+ space  + tb2001_TD_styler._repr_html_(), raw=True)



#**************************************

#graphing the Total Affected
TAdata_2001 = {'Michelle':6011399,'Allison':172000, 'Iris':26446, 'Juliette':3800, 'Chantal':2500}
TAtyp_name2 = list(TAdata_2001.keys())
TAvalues2 = list(TAdata_2001.values())

plt.bar(TAtyp_name2, TAvalues2, color ='blue',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2001 \n (in terms of Total Number of Affected Person)")
plt.show()


#graphing the Total Affected
TDdata_2001 = {'Iris':43,'Michelle':43, 'Allison':41, 'Juliette':3, 'Chantal':0}
TDtyp_name2 = list(TDdata_2001.keys())
TDvalues2 = list(TDdata_2001.values())

plt.bar(TDtyp_name2, TDvalues2, color ='red',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2001 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5f09e" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2001)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f09e_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f09e_level0_row0" class="row_heading level0 row0" >Michelle</th>
#       <td id="T_5f09e_row0_col0" class="data row0 col0" >6011399</td>
#     </tr>
#     <tr>
#       <th id="T_5f09e_level0_row1" class="row_heading level0 row1" >Allison</th>
#       <td id="T_5f09e_row1_col0" class="data row1 col0" >172000</td>
#     </tr>
#     <tr>
#       <th id="T_5f09e_level0_row2" class="row_heading level0 row2" >Iris</th>
# ...

# %%
from IPython.display import display_html 

    #***********************SUB DATAFRAME (YEAR 2002)***************************
    
#creating subdataframe name=typ_y2002 and selecting rows where year=2002
typ_y2002 = new_df.loc[new_df['Year']==2002].copy()
typhoon_names02 = typ_y2002.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected02 = typhoon_names02['Total Affected'].sum()
data2002 = pd.DataFrame(TotalAffected02)
Sorted_Data02_TA = data2002.sort_values(by='Total Affected',ascending=False)
result02_TA = Sorted_Data02_TA.head(5)

#selecting data by column Total Affected
TotalDeath02 = typhoon_names02['Total Deaths'].sum()
data2002_d = pd.DataFrame(TotalDeath02)
Sorted_Data02_TD = data2002_d.sort_values(by='Total Deaths',ascending=False)
result02_TD = Sorted_Data02_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2002_TA_styler = result02_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2002)')
tb2002_TD_styler = result02_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2002)')

display_html(tb2002_TA_styler._repr_html_()+ space  + tb2002_TD_styler._repr_html_(), raw=True)


#**************************************

#graphing the Total Affected
TAdata_2002 = {'Isidore':558030, 'Lili':285595, 'Kenna':9000, 'Julio':500}
TAtyp_name02 = list(TAdata_2002.keys())
TAvalues02 = list(TAdata_2002.values())

plt.bar(TAtyp_name02, TAvalues02, color ='blue',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2002 \n (in terms of Total Number of Affected Person)")
plt.show()


#graphing the Total Affected
TDdata_2002 = {'Isidore':18, 'Lili':15, 'Kenna':3, 'Julio':0}
TDtyp_name02 = list(TDdata_2002.keys())
TDvalues02 = list(TDdata_2002.values())

plt.bar(TDtyp_name02, TDvalues02, color ='red',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2002 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_4113e" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2002)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4113e_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4113e_level0_row0" class="row_heading level0 row0" >Isidore</th>
#       <td id="T_4113e_row0_col0" class="data row0 col0" >558030</td>
#     </tr>
#     <tr>
#       <th id="T_4113e_level0_row1" class="row_heading level0 row1" >Lili</th>
#       <td id="T_4113e_row1_col0" class="data row1 col0" >285595</td>
#     </tr>
#     <tr>
#       <th id="T_4113e_level0_row2" class="row_heading level0 row2" >Kenna</th>
#       <td id="T_4113e_row2_col0" class="data row2 col0" >9000</td>
# ...

# %%
from IPython.display import display_html 

    #***********************SUB DATAFRAME (YEAR 2003)***************************
    
#creating subdataframe name=typ_y2003 and selecting rows where year=2003
typ_y2003 = new_df.loc[new_df['Year']==2003].copy()
typhoon_names03 = typ_y2003.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected03 = typhoon_names03['Total Affected'].sum()
data2003 = pd.DataFrame(TotalAffected03)
Sorted_Data03_TA = data2003.sort_values(by='Total Affected',ascending=False)
result03_TA = Sorted_Data03_TA.head(5)

#selecting data by column Total Affected
TotalDeath03 = typhoon_names03['Total Deaths'].sum()
data2003_d = pd.DataFrame(TotalDeath03)
Sorted_Data03_TD = data2003_d.sort_values(by='Total Deaths',ascending=False)
result03_TD = Sorted_Data03_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2003_TA_styler = result03_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2003)')
tb2003_TD_styler = result03_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2003)')

display_html(tb2003_TA_styler._repr_html_()+ space  + tb2003_TD_styler._repr_html_(), raw=True)


#**************************************

#graphing the Total Affected
TAdata_2003 = {'Isabel':225000, 'Odette':10100, 'Marty':6000,'Ignacio':3000, 'Juan':200}
TAtyp_name03 = list(TAdata_2003.keys())
TAvalues03 = list(TAdata_2003.values())

plt.bar(TAtyp_name03, TAvalues03, color ='blue',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2003 \n (in terms of Total Number of Affected Person)")
plt.show()


#graphing the Total Affected
TDdata_2003 = {'Isidore':18, 'Lili':15, 'Kenna':3, 'Julio':0}
TDtyp_name03 = list(TDdata_2003.keys())
TDvalues03 = list(TDdata_2003.values())

plt.bar(TDtyp_name03, TDvalues03, color ='red',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2003 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f1b51" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2003)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1b51_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1b51_level0_row0" class="row_heading level0 row0" >Isabel</th>
#       <td id="T_f1b51_row0_col0" class="data row0 col0" >225000</td>
#     </tr>
#     <tr>
#       <th id="T_f1b51_level0_row1" class="row_heading level0 row1" >Odette</th>
#       <td id="T_f1b51_row1_col0" class="data row1 col0" >10100</td>
#     </tr>
#     <tr>
#       <th id="T_f1b51_level0_row2" class="row_heading level0 row2" >Marty</th>
#       <td id="T_f1b51_row2_col0" class="data row2 col0" >6000</td>
# ...

# %%
from IPython.display import display_html 

    #***********************SUB DATAFRAME (YEAR 2004)***************************
    
#creating subdataframe name=typ_y2004 and selecting rows where year=2004
typ_y2004 = new_df.loc[new_df['Year']==2004].copy()
typhoon_names04 = typ_y2004.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected04 = typhoon_names04['Total Affected'].sum()
data2004 = pd.DataFrame(TotalAffected04)
Sorted_Data04_TA = data2004.sort_values(by='Total Affected',ascending=False)
result04_TA = Sorted_Data04_TA.head(5)

#selecting data by column Total Affected
TotalDeath04 = typhoon_names04['Total Deaths'].sum()
data2004_d = pd.DataFrame(TotalDeath04)
Sorted_Data04_TD = data2004_d.sort_values(by='Total Deaths',ascending=False)
result04_TD = Sorted_Data04_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2004_TA_styler = result04_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2004)')
tb2004_TD_styler = result04_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2004)')

display_html(tb2004_TA_styler._repr_html_()+ space  + tb2004_TD_styler._repr_html_(), raw=True)


#**************************************

#graphing the Total Affected
TAdata_2004 = {'Frances':5008450, 'Ivan':423919, 'Jeanne':374103, 'Charley':274131, 'Catarina':150060}
TAtyp_name04 = list(TAdata_2004.keys())
TAvalues04 = list(TAdata_2004.values())

plt.bar(TAtyp_name04, TAvalues04, color ='blue',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2004 \n (in terms of Total Number of Affected Person)")
plt.show()


#graphing the Total Affected
TDdata_2004 = {'Jeanne':2782, 'Ivan':123,'Frances':49,'Charley': 15, 'Gaston':7}
TDtyp_name04 = list(TDdata_2004.keys())
TDvalues04 = list(TDdata_2004.values())

plt.bar(TDtyp_name04, TDvalues04, color ='red',
        width = 0.4)
 
plt.xlabel("Event Name")
plt.ylabel("Total No. of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2004 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_66651" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2004)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66651_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66651_level0_row0" class="row_heading level0 row0" >Frances</th>
#       <td id="T_66651_row0_col0" class="data row0 col0" >5008450</td>
#     </tr>
#     <tr>
#       <th id="T_66651_level0_row1" class="row_heading level0 row1" >Ivan</th>
#       <td id="T_66651_row1_col0" class="data row1 col0" >423919</td>
#     </tr>
#     <tr>
#       <th id="T_66651_level0_row2" class="row_heading level0 row2" >Jeanne</th>
#       <td id="T_66651_row2_col0" class="data row2 col0" >374103</td>
# ...

# %%
 from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2005)***************************
    
#creating subdataframe name=typ_y2005 and selecting rows where year=2005
typ_y2005 = new_df.loc[new_df['Year']==2005].copy()
typhoon_names05 = typ_y2005.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected05 = typhoon_names05['Total Affected'].sum()
data2005 = pd.DataFrame(TotalAffected05)
Sorted_Data05_TA = data2005.sort_values(by='Total Affected',ascending=False)
result05_TA = Sorted_Data05_TA.head(5)

#selecting data by column Total Affected
TotalDeath05 = typhoon_names05['Total Deaths'].sum()
data2005_d = pd.DataFrame(TotalDeath05)
Sorted_Data05_TD = data2005_d.sort_values(by='Total Deaths',ascending=False)
result05_TD = Sorted_Data05_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2005_TA_styler = result05_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2005)')
tb2005_TD_styler = result05_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2005)')

display_html(tb2005_TA_styler._repr_html_()+ space  + tb2005_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result05_TA.plot(kind="bar",color="gray")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2005 \n (in terms of Total Affected People)")
plt.show()

result05_TD.plot(kind="bar",color="red")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2005 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_13388" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2005)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13388_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13388_level0_row0" class="row_heading level0 row0" >Stan</th>
#       <td id="T_13388_row0_col0" class="data row0 col0" >2523849</td>
#     </tr>
#     <tr>
#       <th id="T_13388_level0_row1" class="row_heading level0 row1" >Hurricane "Dennis"</th>
#       <td id="T_13388_row1_col0" class="data row1 col0" >2523036</td>
#     </tr>
#     <tr>
#       <th id="T_13388_level0_row2" class="row_heading level0 row2" >Hurricane "Wilma"</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2006)***************************
    
#creating subdataframe name=typ_y2006 and selecting rows where year=2006
typ_y2006 = new_df.loc[new_df['Year']==2006].copy()
typhoon_names06 = typ_y2006.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected06 = typhoon_names06['Total Affected'].sum()
data2006 = pd.DataFrame(TotalAffected06)
Sorted_Data06_TA = data2006.sort_values(by='Total Affected',ascending=False)
result06_TA = Sorted_Data06_TA.head(5)

#selecting data by column Total Affected
TotalDeath06 = typhoon_names06['Total Deaths'].sum()
data2006_d = pd.DataFrame(TotalDeath06)
Sorted_Data06_TD = data2006_d.sort_values(by='Total Deaths',ascending=False)
result06_TD= Sorted_Data06_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2006_TA_styler = result06_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2006)')
tb2006_TD_styler = result06_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2006)')

display_html(tb2006_TA_styler._repr_html_()+ space  + tb2006_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result06_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2006 \n (in terms of Total Affected People)")
plt.show()

result06_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2006 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_b8440" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2006)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8440_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8440_level0_row0" class="row_heading level0 row0" >Lane</th>
#       <td id="T_b8440_row0_col0" class="data row0 col0" >240700</td>
#     </tr>
#     <tr>
#       <th id="T_b8440_level0_row1" class="row_heading level0 row1" >Paul</th>
#       <td id="T_b8440_row1_col0" class="data row1 col0" >20000</td>
#     </tr>
#     <tr>
#       <th id="T_b8440_level0_row2" class="row_heading level0 row2" >Ernesto</th>
#       <td id="T_b8440_row2_col0" class="data row2 col0" >15140</td>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2007)***************************
    
#creating subdataframe name=typ_y2007 and selecting rows where year=2007
typ_y2007 = new_df.loc[new_df['Year']==2007].copy()
typhoon_names07 = typ_y2007.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected07 = typhoon_names07['Total Affected'].sum()
data2007 = pd.DataFrame(TotalAffected07)
Sorted_Data07_TA = data2007.sort_values(by='Total Affected',ascending=False)
result07_TA = Sorted_Data07_TA.head(5)

#selecting data by column Total Affected
TotalDeath07 = typhoon_names07['Total Deaths'].sum()
data2007_d = pd.DataFrame(TotalDeath07)
Sorted_Data07_TD = data2007_d.sort_values(by='Total Deaths',ascending=False)
result07_TD= Sorted_Data07_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2007_TA_styler = result07_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2007)')
tb2007_TD_styler = result07_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2007)')

display_html(tb2007_TA_styler._repr_html_()+ space  + tb2007_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result07_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2007 \n (in terms of Total Affected People)")
plt.show()

result07_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2007 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0cc83" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2007)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cc83_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cc83_level0_row0" class="row_heading level0 row0" >Noel</th>
#       <td id="T_0cc83_row0_col0" class="data row0 col0" >387979</td>
#     </tr>
#     <tr>
#       <th id="T_0cc83_level0_row1" class="row_heading level0 row1" >Felix</th>
#       <td id="T_0cc83_row1_col0" class="data row1 col0" >244931</td>
#     </tr>
#     <tr>
#       <th id="T_0cc83_level0_row2" class="row_heading level0 row2" >Dean</th>
#       <td id="T_0cc83_row2_col0" class="data row2 col0" >206290</td>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2008)***************************
    
#creating subdataframe name=typ_y2008 and selecting rows where year=2008
typ_y2008 = new_df.loc[new_df['Year']==2008].copy()
typhoon_names08 = typ_y2008.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected08 = typhoon_names08['Total Affected'].sum()
data2008 = pd.DataFrame(TotalAffected08)
Sorted_Data08_TA = data2008.sort_values(by='Total Affected',ascending=False)
result08_TA = Sorted_Data08_TA.head(5)

#selecting data by column Total Affected
TotalDeath08 = typhoon_names08['Total Deaths'].sum()
data2008_d = pd.DataFrame(TotalDeath08)
Sorted_Data08_TD = data2008_d.sort_values(by='Total Deaths',ascending=False)
result08_TD= Sorted_Data08_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2008_TA_styler = result08_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2008)')
tb2008_TD_styler = result08_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2008)')

display_html(tb2008_TA_styler._repr_html_()+ space  + tb2008_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result08_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2008 \n (in terms of Total Affected People)")
plt.show()

result08_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2008 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f837c_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2008)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f837c_level0_row0" class="row_heading level0 row0" >Hurricane "Gustav"</th>
#       <td id="T_f837c_row0_col0" class="data row0 col0" >2633282</td>
#     </tr>
#     <tr>
#       <th id="T_f837c_level0_row1" class="row_heading level0 row1" >Hurricane Dolly</th>
#       <td id="T_f837c_row1_col0" class="data row1 col0" >500000</td>
#     </tr>
#     <tr>
#       <th id="T_f837c_level0_row2" class="row_heading level0 row2" >Hurricane Ike</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2009)***************************
    
#creating subdataframe name=typ_y2009 and selecting rows where year=2009
typ_y2009 = new_df.loc[new_df['Year']==2009].copy()
typhoon_names09 = typ_y2009.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected09 = typhoon_names09['Total Affected'].sum()
data2009 = pd.DataFrame(TotalAffected09)
Sorted_Data09_TA = data2009.sort_values(by='Total Affected',ascending=False)
result09_TA = Sorted_Data09_TA.head(5)

#selecting data by column Total Affected
TotalDeath09 = typhoon_names09['Total Deaths'].sum()
data2009_d = pd.DataFrame(TotalDeath09)
Sorted_Data09_TD = data2009_d.sort_values(by='Total Deaths',ascending=False)
result09_TD= Sorted_Data09_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2009_TA_styler = result09_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2009)')
tb2009_TD_styler = result09_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2009)')

display_html(tb2009_TA_styler._repr_html_()+ space  + tb2009_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result09_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2009 \n (in terms of Total Affected People)")
plt.show()

result09_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2009 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_01b16_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2009)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01b16_level0_row0" class="row_heading level0 row0" >Hurricane "Ida"</th>
#       <td id="T_01b16_row0_col0" class="data row0 col0" >149897</td>
#     </tr>
#     <tr>
#       <th id="T_01b16_level0_row1" class="row_heading level0 row1" >Hurricane Jimena</th>
#       <td id="T_01b16_row1_col0" class="data row1 col0" >72000</td>
#     </tr>
#     <tr>
#       <th id="T_01b16_level0_row2" class="row_heading level0 row2" >Hurricane Bill</th>
#       <td id="T_01b16_row2_col0" class="data row2 col0" >12</td>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2010)***************************
    
#creating subdataframe name=typ_y2010 and selecting rows where year=20010
typ_y2010 = new_df.loc[new_df['Year']==2010].copy()
typhoon_names10 = typ_y2010.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected10 = typhoon_names10['Total Affected'].sum()
data2010 = pd.DataFrame(TotalAffected10)
Sorted_Data10_TA = data2010.sort_values(by='Total Affected',ascending=False)
result10_TA = Sorted_Data10_TA.head(5)

#selecting data by column Total Affected
TotalDeath10 = typhoon_names10['Total Deaths'].sum()
data2010_d = pd.DataFrame(TotalDeath10)
Sorted_Data10_TD = data2010_d.sort_values(by='Total Deaths',ascending=False)
result10_TD= Sorted_Data10_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2010_TA_styler = result10_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2010)')
tb2010_TD_styler = result10_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2010)')

display_html(tb2010_TA_styler._repr_html_()+ space  + tb2010_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result10_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2010 \n (in terms of Total Affected People)")
plt.show()

result10_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2010 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0cab5" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2010)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0cab5_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0cab5_level0_row0" class="row_heading level0 row0" >Hurricane Agatha</th>
#       <td id="T_0cab5_row0_col0" class="data row0 col0" >434157</td>
#     </tr>
#     <tr>
#       <th id="T_0cab5_level0_row1" class="row_heading level0 row1" >Hurricane Karl</th>
#       <td id="T_0cab5_row1_col0" class="data row1 col0" >230000</td>
#     </tr>
#     <tr>
#       <th id="T_0cab5_level0_row2" class="row_heading level0 row2" >Hurricane Tomas</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2011)***************************
    
#creating subdataframe name=typ_y2011 and selecting rows where year=2011
typ_y2011 = new_df.loc[new_df['Year']==2011].copy()
typhoon_names11 = typ_y2011.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected11 = typhoon_names11['Total Affected'].sum()
data2011 = pd.DataFrame(TotalAffected11)
Sorted_Data11_TA = data2011.sort_values(by='Total Affected',ascending=False)
result11_TA = Sorted_Data11_TA.head(5)

#selecting data by column Total Affected
TotalDeath11 = typhoon_names11['Total Deaths'].sum()
data2011_d = pd.DataFrame(TotalDeath11)
Sorted_Data11_TD = data2011_d.sort_values(by='Total Deaths',ascending=False)
result11_TD= Sorted_Data11_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2011_TA_styler = result11_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2011)')
tb2011_TD_styler = result11_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2011)')

display_html(tb2011_TA_styler._repr_html_()+ space  + tb2011_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result11_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2011 \n (in terms of Total Affected People)")
plt.show()

result11_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2011 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_df406" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2011)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df406_level0_col0" class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df406_level0_row0" class="row_heading level0 row0" >Hurricane Irene</th>
#       <td id="T_df406_row0_col0" class="data row0 col0" >420815</td>
#     </tr>
#     <tr>
#       <th id="T_df406_level0_row1" class="row_heading level0 row1" >Tropical Storm "Arlene"</th>
#       <td id="T_df406_row1_col0" class="data row1 col0" >300000</td>
#     </tr>
#     <tr>
#       <th id="T_df406_level0_row2" class="row_heading level0 row2" >Tropical storm "Dora"</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2012)***************************
    
#creating subdataframe name=typ_y2012 and selecting rows where year=2012
typ_y2012 = new_df.loc[new_df['Year']==2012].copy()
typhoon_names12 = typ_y2012.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected12 = typhoon_names12['Total Affected'].sum()
data2012 = pd.DataFrame(TotalAffected12)
Sorted_Data12_TA = data2012.sort_values(by='Total Affected',ascending=False)
result12_TA = Sorted_Data12_TA.head(5)

#selecting data by column Total Affected
TotalDeath12 = typhoon_names12['Total Deaths'].sum()
data2012_d = pd.DataFrame(TotalDeath12)
Sorted_Data12_TD = data2012_d.sort_values(by='Total Deaths',ascending=False)
result12_TD= Sorted_Data12_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2012_TA_styler = result12_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2012)')
tb2012_TD_styler = result12_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2012)')

display_html(tb2012_TA_styler._repr_html_()+ space  + tb2012_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result12_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2012 \n (in terms of Total Affected People)")
plt.show()

result12_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2012 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_feaf6_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2012)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_feaf6_level0_row0" class="row_heading level0 row0" >Hurricane Sandy</th>
#       <td id="T_feaf6_row0_col0" class="data row0 col0" >602305</td>
#     </tr>
#     <tr>
#       <th id="T_feaf6_level0_row1" class="row_heading level0 row1" >Hurricane Isaac</th>
#       <td id="T_feaf6_row1_col0" class="data row1 col0" >134018</td>
#     </tr>
#     <tr>
#       <th id="T_feaf6_level0_row2" class="row_heading level0 row2" >Hurricane Carlotta</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2013)***************************
    
#creating subdataframe name=typ_y2013 and selecting rows where year=2013
typ_y2013 = new_df.loc[new_df['Year']==2013].copy()
typhoon_names13 = typ_y2013.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected13 = typhoon_names13['Total Affected'].sum()
data2013 = pd.DataFrame(TotalAffected13)
Sorted_Data13_TA = data2013.sort_values(by='Total Affected',ascending=False)
result13_TA = Sorted_Data13_TA.head(5)

#selecting data by column Total Affected
TotalDeath13 = typhoon_names13['Total Deaths'].sum()
data2013_d = pd.DataFrame(TotalDeath13)
Sorted_Data13_TD = data2013_d.sort_values(by='Total Deaths',ascending=False)
result13_TD= Sorted_Data13_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2013_TA_styler = result13_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2013)')
tb2013_TD_styler = result13_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2013)')

display_html(tb2013_TA_styler._repr_html_()+ space  + tb2013_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result13_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2013 \n (in terms of Total Affected People)")
plt.show()

result13_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2013 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9598d_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2013)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9598d_level0_row0" class="row_heading level0 row0" >Hurricane Manuel </th>
#       <td id="T_9598d_row0_col0" class="data row0 col0" >105000</td>
#     </tr>
#     <tr>
#       <th id="T_9598d_level0_row1" class="row_heading level0 row1" >Hurricane Ingrid</th>
#       <td id="T_9598d_row1_col0" class="data row1 col0" >50000</td>
#     </tr>
#     <tr>
#       <th id="T_9598d_level0_row2" class="row_heading level0 row2" >Hurricane Barbara</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2014)***************************
    
#creating subdataframe name=typ_y2014 and selecting rows where year=2014
typ_y2014 = new_df.loc[new_df['Year']==2014].copy()
typhoon_names14 = typ_y2014.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected14 = typhoon_names14['Total Affected'].sum()
data2014 = pd.DataFrame(TotalAffected14)
Sorted_Data14_TA = data2014.sort_values(by='Total Affected',ascending=False)
result14_TA = Sorted_Data14_TA.head(5)

#selecting data by column Total Affected
TotalDeath14 = typhoon_names14['Total Deaths'].sum()
data2014_d = pd.DataFrame(TotalDeath14)
Sorted_Data14_TD = data2014_d.sort_values(by='Total Deaths',ascending=False)
result14_TD= Sorted_Data14_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2014_TA_styler = result14_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2014)')
tb2014_TD_styler = result14_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2014)')

display_html(tb2014_TA_styler._repr_html_()+ space  + tb2014_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result14_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2014 \n (in terms of Total Affected People)")
plt.show()

result14_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2014 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4199_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2014)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4199_level0_row0" class="row_heading level0 row0" >Boris</th>
#       <td id="T_d4199_row0_col0" class="data row0 col0" >100000</td>
#     </tr>
#     <tr>
#       <th id="T_d4199_level0_row1" class="row_heading level0 row1" >Hurricane Odile</th>
#       <td id="T_d4199_row1_col0" class="data row1 col0" >75135</td>
#     </tr>
#     <tr>
#       <th id="T_d4199_level0_row2" class="row_heading level0 row2" >Hurricane Marie</th>
#       <td id="T_d4199_row2_col0" class="data row2 col0" >30000</td>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2015)***************************
    
#creating subdataframe name=typ_y2015 and selecting rows where year=2015
typ_y2015 = new_df.loc[new_df['Year']==2015].copy()
typhoon_names15 = typ_y2015.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected15 = typhoon_names15['Total Affected'].sum()
data2015 = pd.DataFrame(TotalAffected15)
Sorted_Data15_TA = data2015.sort_values(by='Total Affected',ascending=False)
result15_TA = Sorted_Data15_TA.head(5)

#selecting data by column Total Affected
TotalDeath15 = typhoon_names15['Total Deaths'].sum()
data2015_d = pd.DataFrame(TotalDeath15)
Sorted_Data15_TD = data2015_d.sort_values(by='Total Deaths',ascending=False)
result15_TD= Sorted_Data15_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2015_TA_styler = result15_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2015)')
tb2015_TD_styler = result15_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2015)')

display_html(tb2015_TA_styler._repr_html_()+ space  + tb2015_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result15_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2015 \n (in terms of Total Affected People)")
plt.show()

result15_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2015 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_dcf44_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2015)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcf44_level0_row0" class="row_heading level0 row0" >Hurricane Erika</th>
#       <td id="T_dcf44_row0_col0" class="data row0 col0" >32696</td>
#     </tr>
#     <tr>
#       <th id="T_dcf44_level0_row1" class="row_heading level0 row1" >Hurricane Patricia</th>
#       <td id="T_dcf44_row1_col0" class="data row1 col0" >15000</td>
#     </tr>
#     <tr>
#       <th id="T_dcf44_level0_row2" class="row_heading level0 row2" >Hurricane 'Joaquin'</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2016)***************************
    
#creating subdataframe name=typ_y2016 and selecting rows where year=2016
typ_y2016 = new_df.loc[new_df['Year']==2016].copy()
typhoon_names16 = typ_y2016.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected16 = typhoon_names16['Total Affected'].sum()
data2016 = pd.DataFrame(TotalAffected16)
Sorted_Data16_TA = data2016.sort_values(by='Total Affected',ascending=False)
result16_TA = Sorted_Data16_TA.head(5)

#selecting data by column Total Affected
TotalDeath16 = typhoon_names16['Total Deaths'].sum()
data2016_d = pd.DataFrame(TotalDeath16)
Sorted_Data16_TD = data2016_d.sort_values(by='Total Deaths',ascending=False)
result16_TD= Sorted_Data16_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2016_TA_styler = result16_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2016)')
tb2016_TD_styler = result16_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2016)')

display_html(tb2016_TA_styler._repr_html_()+ space  + tb2016_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result16_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2016 \n (in terms of Total Affected People)")
plt.show()

result16_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2016 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_03281_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2016)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03281_level0_row0" class="row_heading level0 row0" >Hurricane 'Matthew'</th>
#       <td id="T_03281_row0_col0" class="data row0 col0" >2440487</td>
#     </tr>
#     <tr>
#       <th id="T_03281_level0_row1" class="row_heading level0 row1" >Tropical storm Otto</th>
#       <td id="T_03281_row1_col0" class="data row1 col0" >72570</td>
#     </tr>
#     <tr>
#       <th id="T_03281_level0_row2" class="row_heading level0 row2" >Tropical storm 'Earl'</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2017)***************************
    
#creating subdataframe name=typ_y2017 and selecting rows where year=2017
typ_y2017 = new_df.loc[new_df['Year']==2017].copy()
typhoon_names17 = typ_y2017.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected17 = typhoon_names17['Total Affected'].sum()
data2017 = pd.DataFrame(TotalAffected17)
Sorted_Data17_TA = data2017.sort_values(by='Total Affected',ascending=False)
result17_TA = Sorted_Data17_TA.head(5)

#selecting data by column Total Affected
TotalDeath17 = typhoon_names17['Total Deaths'].sum()
data2017_d = pd.DataFrame(TotalDeath17)
Sorted_Data17_TD = data2017_d.sort_values(by='Total Deaths',ascending=False)
result17_TD= Sorted_Data17_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2017_TA_styler = result17_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2017)')
tb2017_TD_styler = result17_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2017)')

display_html(tb2017_TA_styler._repr_html_()+ space  + tb2017_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result17_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2017 \n (in terms of Total Affected People)")
plt.show()

result17_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2017 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_684c1_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2017)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_684c1_level0_row0" class="row_heading level0 row0" >Hurricane 'Irma'</th>
#       <td id="T_684c1_row0_col0" class="data row0 col0" >10138842</td>
#     </tr>
#     <tr>
#       <th id="T_684c1_level0_row1" class="row_heading level0 row1" >Hurricane 'Maria'</th>
#       <td id="T_684c1_row1_col0" class="data row1 col0" >927397</td>
#     </tr>
#     <tr>
#       <th id="T_684c1_level0_row2" class="row_heading level0 row2" >Hurricane Harvey</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2018)***************************
    
#creating subdataframe name=typ_y2018 and selecting rows where year=2018
typ_y2018 = new_df.loc[new_df['Year']==2018].copy()
typhoon_names18 = typ_y2018.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected18 = typhoon_names18['Total Affected'].sum()
data2018 = pd.DataFrame(TotalAffected18)
Sorted_Data18_TA = data2018.sort_values(by='Total Affected',ascending=False)
result18_TA = Sorted_Data18_TA.head(5)

#selecting data by column Total Affected
TotalDeath18 = typhoon_names18['Total Deaths'].sum()
data2018_d = pd.DataFrame(TotalDeath18)
Sorted_Data18_TD = data2018_d.sort_values(by='Total Deaths',ascending=False)
result18_TD= Sorted_Data18_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2018_TA_styler = result18_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2018)')
tb2018_TD_styler = result18_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2018)')

display_html(tb2018_TA_styler._repr_html_()+ space  + tb2018_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result18_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2018 \n (in terms of Total Affected People)")
plt.show()

result18_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2018 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae54d_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2018)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae54d_level0_row0" class="row_heading level0 row0" >Hurricane Florence</th>
#       <td id="T_ae54d_row0_col0" class="data row0 col0" >1500000</td>
#     </tr>
#     <tr>
#       <th id="T_ae54d_level0_row1" class="row_heading level0 row1" >Tropical storm 'Alberto'</th>
#       <td id="T_ae54d_row1_col0" class="data row1 col0" >40000</td>
#     </tr>
#     <tr>
#       <th id="T_ae54d_level0_row2" class="row_heading level0 row2" >Hurricane Willa</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2019)***************************
    
#creating subdataframe name=typ_y2019 and selecting rows where year=2019
typ_y2019 = new_df.loc[new_df['Year']==2019].copy()
typhoon_names19 = typ_y2019.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected19 = typhoon_names19['Total Affected'].sum()
data2019 = pd.DataFrame(TotalAffected19)
Sorted_Data19_TA = data2019.sort_values(by='Total Affected',ascending=False)
result19_TA = Sorted_Data19_TA.head(5)

#selecting data by column Total Affected
TotalDeath19 = typhoon_names19['Total Deaths'].sum()
data2019_d = pd.DataFrame(TotalDeath19)
Sorted_Data19_TD = data2019_d.sort_values(by='Total Deaths',ascending=False)
result19_TD= Sorted_Data19_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2019_TA_styler = result19_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2019)')
tb2019_TD_styler = result19_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2019)')

display_html(tb2019_TA_styler._repr_html_()+ space  + tb2019_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result19_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2019 \n (in terms of Total Affected People)")
plt.show()

result19_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2019 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_34a1b_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2019)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34a1b_level0_row0" class="row_heading level0 row0" >Tropical cyclone 'Dorian'</th>
#       <td id="T_34a1b_row0_col0" class="data row0 col0" >14940</td>
#     </tr>
#     <tr>
#       <th id="T_34a1b_level0_row1" class="row_heading level0 row1" >Tropical storm ' Imelda'</th>
#       <td id="T_34a1b_row1_col0" class="data row1 col0" >1000</td>
#     </tr>
#     <tr>
#       <th id="T_34a1b_level0_row2" class="row_heading level0 row2" >Tropical storm 'Narda'</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2020)***************************
    
#creating subdataframe name=typ_y2020 and selecting rows where year=2020
typ_y2020 = new_df.loc[new_df['Year']==2020].copy()
typhoon_names20 = typ_y2020.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected20 = typhoon_names20['Total Affected'].sum()
data2020 = pd.DataFrame(TotalAffected20)
Sorted_Data20_TA = data2020.sort_values(by='Total Affected',ascending=False)
result20_TA = Sorted_Data20_TA.head(5)

#selecting data by column Total Affected
TotalDeath20 = typhoon_names20['Total Deaths'].sum()
data2020_d = pd.DataFrame(TotalDeath20)
Sorted_Data20_TD = data2020_d.sort_values(by='Total Deaths',ascending=False)
result20_TD= Sorted_Data20_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2020_TA_styler = result20_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2020)')
tb2020_TD_styler = result20_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2020)')

display_html(tb2020_TA_styler._repr_html_()+ space  + tb2020_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result20_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2020 \n (in terms of Total Affected People)")
plt.show()

result20_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2020 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_f246c_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2020)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f246c_level0_row0" class="row_heading level0 row0" >Hurricane 'Eta'</th>
#       <td id="T_f246c_row0_col0" class="data row0 col0" >7152272</td>
#     </tr>
#     <tr>
#       <th id="T_f246c_level0_row1" class="row_heading level0 row1" >Hurricane 'Iota'</th>
#       <td id="T_f246c_row1_col0" class="data row1 col0" >1837298</td>
#     </tr>
#     <tr>
#       <th id="T_f246c_level0_row2" class="row_heading level0 row2" >Tropical storm 'Amanda'</th>
# ...

# %%
from IPython.display import display_html 
    #***********************SUB DATAFRAME (YEAR 2021)***************************
    
#creating subdataframe name=typ_y2021 and selecting rows where year=2021
typ_y2021 = new_df.loc[new_df['Year']==2021].copy()
typhoon_names21 = typ_y2021.groupby('Event Name')

#selecting data by column Total Affected
TotalAffected21 = typhoon_names21['Total Affected'].sum()
data2021 = pd.DataFrame(TotalAffected21)
Sorted_Data21_TA = data2021.sort_values(by='Total Affected',ascending=False)
result21_TA = Sorted_Data21_TA.head(5)

#selecting data by column Total Affected
TotalDeath21 = typhoon_names21['Total Deaths'].sum()
data2021_d = pd.DataFrame(TotalDeath21)
Sorted_Data21_TD = data2021_d.sort_values(by='Total Deaths',ascending=False)
result21_TD= Sorted_Data21_TD.head(5)

#displaying the two tables side by side
space = "\xa0" * 30
tb2021_TA_styler = result21_TA.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Affected People by Typhoons \n (Year 2021)')
tb2021_TD_styler = result21_TD.style.set_table_attributes("style='display:inline'").set_caption('Total Numbers of Deaths by Typhoons \n(Year 2021)')

display_html(tb2021_TA_styler._repr_html_()+ space  + tb2021_TD_styler._repr_html_(), raw=True)

#********************************

#graphing of data
result21_TA.plot(kind="bar",color="b")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Affected")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2021 \n (in terms of Total Affected People)")
plt.show()

result21_TD.plot(kind="bar",color="r")
plt.xlabel("Event Name")
plt.ylabel("Total Number of Deaths")
plt.title("\nTyphoons that Brought Greatest Number of Casualties in America in Year 2021 \n (in terms of Total Deaths)")
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7442d_" style='display:inline'>
#   <caption>Total Numbers of Affected People by Typhoons
#  (Year 2021)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Total Affected</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Event Name</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7442d_level0_row0" class="row_heading level0 row0" >Tropical storm 'Ida'</th>
#       <td id="T_7442d_row0_col0" class="data row0 col0" >14000</td>
#     </tr>
#     <tr>
#       <th id="T_7442d_level0_row1" class="row_heading level0 row1" >Tropical cyclone 'Fred'</th>
#       <td id="T_7442d_row1_col0" class="data row1 col0" >4025</td>
#     </tr>
#     <tr>
#       <th id="T_7442d_level0_row2" class="row_heading level0 row2" >Hurricane 'Elsa'</th>
# ...

# %% [markdown]
# 2. Acquire the data about the top 5 countries who had the greatest number of deaths, injured, and affected individuals from the typhoons on the year 2000-2022.

# %%
#***********************SUB DATAFRAME (Top 5 countries with the highest number of affected individuals by typhoons from 2000-2022)***************************

# First, drop duplicates function was used to find the exact names and nubmer of countries that were included on the record without duplicates. There are 38 countries in total. 

Country_names = new_df["Country"].drop_duplicates() 
# Creating a new dataframe called `Country_names` that contains the unique values of the `Country` column in the `new_df` dataframe

data = pd.DataFrame(Country_names) #Creating a new dataframe called `data` that contains the unique values of the `Country` column in the `new_df` dataframe.


print(data) #Printing the dataframe `data`
# Out:
#                                 Country
# 0                                Belize
# 1                                Mexico
# 2                             Nicaragua
# 3                           El Salvador
# 4        United States of America (the)
# 5                         Bahamas (the)
# 8                              Barbados
# 9                                  Cuba
# 10                 Cayman Islands (the)
# 11             Dominican Republic (the)
# 12                            Guatemala
# 13                             Honduras
# 14                                Haiti
# 15                              Jamaica
# 21                              Grenada
# 39     Saint Vincent and the Grenadines
# 40                              Bermuda
# 41                               Canada
# 52                               Brazil
# 61                          Saint Lucia
# 64                          Puerto Rico
# 73       Turks and Caicos Islands (the)
# ...

# %%
#Acquiring the top 5 countries with the highest number of total deaths caused by typhoons from 2000-2022 using groupby and sum function of pandas

ByCountryDeath = new_df.groupby('Country')
TotalData = ByCountryDeath['Total Deaths'].sum()
data = pd.DataFrame(TotalData)
SortedData = data.sort_values(by='Total Deaths',ascending=False)
result = SortedData.head(5)
display(result)
# Out:
#                                 Total Deaths
# Country
# Haiti                                   4343
# United States of America (the)          2912
# Guatemala                               1896
# Mexico                                   664
# El Salvador                              405

# %%
#Acquiring the top 5 countries with the highest number of total injured individuals caused by typhoons from 2000-2022 using groupby and sum function of pandas

ByCountryInjured = new_df.groupby('Country')
TotalData = ByCountryDeath['No Injured'].sum()
data = pd.DataFrame(TotalData)
SortedData = data.sort_values(by='No Injured',ascending=False)
result = SortedData.head(5)
display(result)
# Out:
#            No Injured
# Country
# Haiti            3393
# Guatemala         581
# Belize            570
# Mexico            368
# Dominica          150

# %%
#Acquiring the top 5 countries with the highest number of total affected individuals caused by typhoons from 2000-2022 using groupby and sum function of pandas

ByCountry = new_df.groupby('Country')
TotalData = ByCountry['Total Affected'].sum()
data = pd.DataFrame(TotalData)
SortedData = data.sort_values(by='Total Affected',ascending=False)
result = SortedData.head(5)
display(result)
# Out:
#                                 Total Affected
# Country
# Cuba                                  20202593
# United States of America (the)        11279675
# Mexico                                 6176551
# Honduras                               5380420
# Guatemala                              3841847

# %% [markdown]
# 3. Acquire the data about the name of countries who had the least number of deaths, injured, and affected individuals from the typhoons on 2000-2022.

# %%
#Acquiring the top 11 countries with the lowest number of total deaths caused by typhoons from 2000-2022 using groupby and sum function of pandas

ByCountryDeath = new_df.groupby('Country')
TotalData = ByCountryDeath['Total Deaths'].sum()
data = pd.DataFrame(TotalData)
SortedData = data.sort_values(by='Total Deaths',ascending=True)
result = SortedData.head(11)
display(result)
# Out:
#                                 Total Deaths
# Country
# Saint Kitts and Nevis                      0
# Antigua and Barbuda                        1
# Trinidad and Tobago                        1
# Barbados                                   2
# Cayman Islands (the)                       2
# Martinique                                 2
# Canada                                     3
# Anguilla                                   4
# Turks and Caicos Islands (the)             4
# Bermuda                                    4
# Brazil                                     4

# %%
#Acquiring the top 19 countries with the lowest number of total injured individuals caused by typhoons from 2000-2022 using groupby and sum function of pandas

ByCountryInjured = new_df.groupby('Country')
TotalData = ByCountryDeath['No Injured'].sum()
data = pd.DataFrame(TotalData)
SortedData = data.sort_values(by='No Injured',ascending=True)
result = SortedData.head(19)
display(result)
# Out:
#                                 No Injured
# Country
# Anguilla                                 0
# Turks and Caicos Islands (the)           0
# Trinidad and Tobago                      0
# Saint Lucia                              0
# Saint Kitts and Nevis                    0
# Saint Barthélemy                         0
# Puerto Rico                              0
# Panama                                   0
# Nicaragua                                0
# Virgin Island (British)                  0
# Grenada                                  0
# Virgin Island (U.S.)                     0
# Bahamas (the)                            0
# Barbados                                 0
# Antigua and Barbuda                      0
# Costa Rica                               0
# Bermuda                                  0
# Colombia                                 0
# Cayman Islands (the)                     0

# %%
#Acquiring the top 5 countries with the lowest number of total affected individuals caused by typhoons from 2000-2022 using groupby and sum function of pandas

ByCountry = new_df.groupby('Country')
TotalData = ByCountry['Total Affected'].sum()
data = pd.DataFrame(TotalData)
SortedData = data.sort_values(by='Total Affected',ascending=True)
result = SortedData.head(5)
display(result)
# Out:
#                          Total Affected
# Country
# Virgin Island (U.S.)                  0
# Bermuda                               0
# Saint Barthélemy                      0
# Virgin Island (British)               0
# Martinique                            8

# %% [markdown]
# 4. Get the information that shows the top 5 countries who were most affected in terms of economy (dollars) by typhoons from the year 2000-2022.

# %%
#sorting data for most affected in terms of economy
countrynames = new_df.groupby('Country')
totaldollars = countrynames["Total Damages, Adjusted ('000 US$)"].sum()
td_frame = pd.DataFrame(totaldollars)
SortedData_dollars = td_frame.sort_values(by="Total Damages, Adjusted ('000 US$)",ascending=False)
result_dollars = SortedData_dollars.head(5)
display(result_dollars)

#graphing of data
result_dollars.plot(kind="bar",color="magenta")
plt.xlabel("Country")
plt.ylabel("Total Damages, Adjusted ('000 US$)")
plt.title("\nTop 5 Most Affected Countries in Terms of Economy (dollars) \n by typhoons from the year 2000-2022\n")
plt.show()
# Out:
#                                 Total Damages, Adjusted ('000 US$)
# Country
# United States of America (the)                           758704028
# Puerto Rico                                               75979583
# Mexico                                                    34988807
# Cuba                                                      13638965
# Bahamas (the)                                              7117040

# %%
new_df
# Out:
#             Dis No  Year Disaster Type  Disaster Subtype  \
# 0    2000-0642-BLZ  2000         Storm  Tropical cyclone
# 1    2000-0643-MEX  2000         Storm  Tropical cyclone
# 2    2000-0644-NIC  2000         Storm  Tropical cyclone
# 3    2000-0645-SLV  2000         Storm  Tropical cyclone
# 4    2000-0652-USA  2000         Storm  Tropical cyclone
# ..             ...   ...           ...               ...
# 381  2021-0531-USA  2021         Storm  Tropical cyclone
# 382  2021-0532-USA  2021         Storm  Tropical cyclone
# 383  2021-0551-USA  2021         Storm  Tropical cyclone
# 384  2021-0583-USA  2021         Storm  Tropical cyclone
# 385  2021-0373-VCT  2021         Storm  Tropical cyclone
#
#                       Event Name                           Country  \
# 0                          Keith                            Belize
# 1                          Keith                            Mexico
# 2                          Keith                         Nicaragua
# ...

# %% [markdown]
# 5. Determine which top 5 typhoons are the strongest based from the x variable ‘Dis Mag Scale’ or the magnitude of the disaster at its epicenter with the values in kph (kilometer per Hour).

# %%
ByTyphoons = new_df.iloc[:,[4, 17]] 
data = pd.DataFrame(ByTyphoons)
SortedData = data.sort_values(by='Dis Mag Value',ascending=False)
result = SortedData.head(5)
display(result)
# Out:
#                     Event Name  Dis Mag Value
# 313           Hurricane 'Irma'          300.0
# 325  Tropical cyclone 'Dorian'          298.0
# 276           Hurricane 'Irma'          295.0
# 273           Hurricane 'Irma'          285.0
# 100                    Katrina          280.0
